# %% [markdown]
# <a href="https://colab.research.google.com/github/depak-kumar/heart_disease_predict/blob/main/crop_recomender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
import pandas as pd
import numpy as np
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! streamlit run /content/drive/MyDrive/app4.py & npx localtunnel --port 8501
# Out:
# [#.................] - fetchMetadata: sill resolveWithNewModule follow-redirect
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.86.170.67:8501
#
# npx: installed 22 in 3.498s
# your url is: https://evil-glasses-scream.loca.lt
# 2023-08-30 14:29:17.900488: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-30 14:29:18.992857: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-08-30 14:31:06.908 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 552, in _run_script
#     exec(code, module.__dict__)
# ...
